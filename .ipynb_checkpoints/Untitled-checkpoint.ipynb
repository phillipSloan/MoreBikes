# %%
import pandas as pd
from pathlib import Path
import numpy as np

from sklearn.ensemble import RandomForestRegressor

# %%
# Adding all files into one DataFrame
df = []
for path in Path('./Train/Train').rglob('*.csv'):
    tmp = pd.read_csv(path)
    df.append(tmp)

df = pd.concat(df, ignore_index=True)

def convert_weekdays(df):
    df = df.replace(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
    [1, 2, 3, 4, 5, 6, 7])
    return df


del df["month"]
del df["year"]

df = convert_weekdays(df)

df = df.dropna(axis='rows')

# %%
# Changing the weekday column from 'Monday'...'Sunday' to binary.
#df = pd.get_dummies(df,columns=['weekday'])

# %%
df
# Out:
#        station   latitude  longitude  numDocks     timestamp  day  hour  \
# 171        206  39.472030  -0.370965        24  1.412730e+09    8     3
# 172        206  39.472030  -0.370965        24  1.412734e+09    8     4
# 173        206  39.472030  -0.370965        24  1.412737e+09    8     5
# 174        206  39.472030  -0.370965        24  1.412741e+09    8     6
# 175        206  39.472030  -0.370965        24  1.412744e+09    8     7
# ...        ...        ...        ...       ...           ...  ...   ...
# 55870      208  39.469056  -0.375728        34  1.414778e+09   31    19
# 55871      208  39.469056  -0.375728        34  1.414782e+09   31    20
# 55872      208  39.469056  -0.375728        34  1.414786e+09   31    21
# 55873      208  39.469056  -0.375728        34  1.414789e+09   31    22
# 55874      208  39.469056  -0.375728        34  1.414793e+09   31    23
#
#        weekhour  isHoliday  windMaxSpeed.m.s  ...  temperature.C  \
# 171          52          0               1.6  ...           21.5
# 172          53          0               3.2  ...           20.8
# 173          54          0               3.2  ...           19.8
# 174          55          0               8.0  ...           19.7
# 175          56          0               9.7  ...           19.6
# ...         ...        ...               ...  ...            ...
# 55870       116          0               9.7  ...           20.2
# 55871       117          0               6.4  ...           20.2
# 55872       118          0               3.2  ...           20.0
# 55873       119          0               0.0  ...           19.3
# 55874       120          0               4.8  ...           19.1
#
#        relHumidity.HR  airPressure.mb  precipitation.l.m2  bikes_3h_ago  \
# 171              59.0          1011.5                 0.0           0.0
# 172              62.0          1011.1                 0.0           0.0
# 173              67.0          1010.9                 0.0           0.0
# 174              66.0          1010.8                 0.0           0.0
# 175              67.0          1011.1                 0.0           0.0
# ...               ...             ...                 ...           ...
# 55870            80.0          1023.5                 0.0          12.0
# 55871            82.0          1023.9                 0.0           9.0
# 55872            83.0          1024.0                 0.0           6.0
# 55873            84.0          1024.4                 0.0           6.0
# 55874            86.0          1024.1                 0.0           7.0
#
#        full_profile_3h_diff_bikes  full_profile_bikes  \
# 171                          0.00                0.00
# 172                          0.00                0.00
# 173                          0.00                0.00
# 174                          1.00                1.00
# 175                          2.00                2.00
# ...                           ...                 ...
# 55870                        0.25               10.00
# 55871                       -2.25                6.50
# 55872                       -1.75                6.00
# 55873                       -6.75                3.25
# 55874                       -3.50                3.00
#
#        short_profile_3h_diff_bikes  short_profile_bikes  bikes
# 171                           0.00                 0.00    0.0
# 172                           0.00                 0.00    0.0
# 173                           0.00                 0.00    0.0
# 174                           1.00                 1.00    1.0
# 175                           2.00                 2.00    4.0
# ...                            ...                  ...    ...
# 55870                         0.25                10.00    6.0
# 55871                        -2.25                 6.50    7.0
# 55872                        -1.75                 6.00    6.0
# 55873                        -6.75                 3.25    5.0
# 55874                        -3.50                 3.00   11.0
#
# [42600 rows x 22 columns]

# %%
forest = RandomForestRegressor(n_jobs=6)

forest.fit(df.iloc[:,:-1], df["bikes"])

print(forest.feature_importances_)
print(df.columns)
# Out:
# [0.02351163 0.01735852 0.02126385 0.02498205 0.0234431  0.00583122
#  0.02152336 0.02383259 0.00731518 0.0107882  0.00747903 0.01048328
#  0.0180968  0.01659819 0.02062044 0.         0.44515184 0.0719124
#  0.07800402 0.07251292 0.07929139]
# Index(['station', 'latitude', 'longitude', 'numDocks', 'timestamp', 'day',
#        'hour', 'weekhour', 'isHoliday', 'windMaxSpeed.m.s',
#        'windMeanSpeed.m.s', 'windDirection.grades', 'temperature.C',
#        'relHumidity.HR', 'airPressure.mb', 'precipitation.l.m2',
#        'bikes_3h_ago', 'full_profile_3h_diff_bikes', 'full_profile_bikes',
#        'short_profile_3h_diff_bikes', 'short_profile_bikes', 'bikes'],
#       dtype='object')
